# %%
import pandas as pd

# %%
 pd.read_csv("/content/drive/MyDrive/VU/BACHELOR'S DATA/clean_data/tweets/BTC_tweets.csv", lineterminator = "\n")
# Out:
#                                                      tweet         username  \
# 0        $BTC Price: $47933 $ETH Price: $3577 $LTC Pric...      coincapitan
# 1        @mikealfred @philipmak Zero chance $BTC will b...       tallseller
# 2        $BTC is going to $80,000 by October 31st and $...        0xgoodies
# 3        Premium Membership Update!  Made a few updates...   charts_bitcoin
# 4              Kind of agree. $TSLA $BTC. That’s about it.          umbisam
# ...                                                    ...              ...
# 1685860  $ANY here is the DD link... No excuse on missi...   boondockqueens
# 1685861  $clv @clover_finance @Polkadot They want your ...     cspratt15139
# 1685862  Jul 22, 2021: The current Mayer Multiple is 0....  tipmayermultple
# 1685863  @ARKInvest @CathieDWood Ok, it's now Bitcoin t...   marian55276549
# 1685864  $AMB #AMB going to 2X from here from 90 Satosh...   dcryptoservice
#
#                    timestamp
# ...

# %%
pd.read_csv("/content/drive/MyDrive/VU/BACHELOR'S DATA/raw_data/tweets/BTC2021-01-01.csv", lineterminator = "\n").drop([
    "place","geo","source","user_rt_id","user_rt","retweet_id", "reply_to","quote_url","video","near","retweet_date", "translate", "trans_src", "trans_dest\r", "thumbnail","mentions","id","conversation_id","user_id","language","urls","photos","date","link","hashtags","timezone"
], axis = 1)
# Out:
#                    created_at      time         username  \
# 0     2021-01-02 01:59:37 EET  01:59:37     jeremysleeks
# 1     2021-01-02 01:59:28 EET  01:59:28   pablo_algoboss
# 2     2021-01-02 01:59:23 EET  01:59:23    newscryptobot
# 3     2021-01-02 01:59:20 EET  01:59:20  realcryptosheet
# 4     2021-01-02 01:58:47 EET  01:58:47        ultrahdr6
# ...                       ...       ...              ...
# 5054  2021-01-01 02:00:03 EET  02:00:03      whaletrades
# 5055  2021-01-01 02:00:02 EET  02:00:02         indacoin
# 5056  2021-01-01 02:00:02 EET  02:00:02   btchourlyprice
# 5057  2021-01-01 02:00:00 EET  02:00:00     binancerekts
# 5058  2021-01-01 02:00:00 EET  02:00:00     binancerekts
#
#                       name                                              tweet  \
# 0            Jeremy Sleeks  $BTC $ETH $LINK  $UNI Last ticket check before...
# 1                Don Pablo  Not long now IMO.. big impulse moves coming fo...
# ...

# %%
import matplotlib.pyplot as plt

# %%
d = pd.read_csv("/content/drive/MyDrive/VU/BACHELOR'S DATA/train_val_data/BTC_train.csv")

# %%
for i in range(min(20,d.shape[0])):
  d.iloc[i, 1:].plot()
  plt.xlabel('Indeksas')
  plt.ylabel('% Pokytis')
  plt.show()
