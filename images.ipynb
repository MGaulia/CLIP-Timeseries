# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("train_val_data/BTC_train.csv", lineterminator='\n')

# %%
fig = plt.figure()
data.iloc[2][1:].plot(figsize = (15, 7))
fig.savefig('3.png', dpi=fig.dpi)

# %%
plt.savefig("t1.png")
